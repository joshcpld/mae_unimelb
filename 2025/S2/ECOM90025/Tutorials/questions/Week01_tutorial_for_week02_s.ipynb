# %% [markdown]
# # Tutorial
#
# You have seen the popular student [competition case](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/overview/description).
# Now it is my turn to give you a [fair game](https://www.kaggle.com/t/f5f7783abf31495f9593b3d93a18f9eb) so that no exsiting notebook can be used.
#
# Your task is to predict $Y$ by using $50$ $X$ variables ($X_1,...,X_{50}$). In this assignment, **only** use the unconditional mean to start prediction.
#
# 1. Make a copy of this file.
# 1. Read the training sample to a Pandas dataframe.
# 1. compute the unconditional mean of $Y$.
# 1. Submit a file and get your Kaggle score screenshot.
# 1. Show your screenshot in the notebook.
#
#
# Feel free to use AI for help.

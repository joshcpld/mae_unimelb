# %% [markdown]
# # Tutorial
#
# Revisit the forensic glass data to estimate another linear model by using LASSO, as well as to try the SVM.
#
# 1. Follow the textbook to have interactions of `RI` with the other variables as additonal covariates. Build the formula in order to extract the design matrix $X$.
# 1. Estimate a Multinomial Logistic model and interpret results briefly. Why aren't restrictions needed?
# 1. Apply LASSO + Cross Validation to find an optimal penalty value.
# 1. Estimate the LASSO with the previous penalty term's value.
# 1. Use one type as a category and other types as the other category. By doing so, multiple categories become two, so that Logistic regression can be carried out. Try the LASSO on Logistic Model and the RBF kernel SVM to compare. Gee, you have so many scores to choose from, which one then?
#
# - Repeating existing code is not sufficient. You are expected to be able to explain what the code does for each step. Your tutor is watching...
#
# <img src="https://www.dropbox.com/scl/fi/7z8guvr72iefaphtm3dgq/watching.jpg?rlkey=dzrbd478sl3jlrgnbmtqnedxr&st=0of35app&dl=1" width = 100>

# %% [markdown]
# # House Keeping

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import plotly.express as px
import plotly.graph_objects as go
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss

from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from sklearn.inspection import DecisionBoundaryDisplay

import warnings
from plotly.subplots import make_subplots

def sy_logit_deviance(y_true, y_pred):
    dev = -2 * np.sum(y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred))
    return dev

# %%
df_fgl = pd.read_csv("https://www.dropbox.com/scl/fi/4m46hl6wul60pjhvmgqkl/fgl.csv?rlkey=0q33wenv2tqxpy3ldypptqeyj&dl=1")
df_fgl
# Out:
#        RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  type
# 0    3.01  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0  WinF
# 1   -0.39  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0  WinF
# 2   -1.82  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0  WinF
# 3   -0.34  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0  WinF
# 4   -0.58  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0  WinF
# ..    ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209 -1.77  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0  Head
# 210 -1.15  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0  Head
# 211  2.65  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0  Head
# 212 -1.49  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0  Head
# 213 -0.89  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0  Head
#
# [214 rows x 10 columns]
